# %% [markdown]
# ## Esercizio 1.5: Esperimento content-to-form
#
# Partendo dal nostro file contenente le definizioni, eseguiamo una fase di processing e counting per ottenere una raccolta di parole - numero apparizioni e usiamo tale raccolta per calcolare l'overlapp con i synset di wordnet.
# In base ai risultati dell'overlapp ordiniamo i synset più probabili.
#
# ![slide%20esercizio.png](attachment:slide%20esercizio.png)
#
#
# Creiamo un metodo per leggere il file.csv

# %%
import os
import csv
import pprint
def read_csv(file_name):
    meanings_map = {}
    dir = os.getcwd()
    with open(dir + '/' + file_name, "r") as csv_file:
        words = csv_file.readline().replace('\n','').split(',')
        csv_reader = csv.reader(csv_file, delimiter=',')
        for row in csv_reader:
            for i in range(1, 5):
                if not meanings_map.keys().__contains__(words[i]):
                    meanings_map[words[i]] = []
                meanings_map[words[i]].append(row[i]) if len(row[i]) > 0 else None
    return meanings_map

# Esempio output
# pprint.pprint(read_csv('defs.csv'))

# %% [markdown]
# ## Pre-processing & Counting
# Dal risultato di `read_csv('defs.csv')` otteniamo una dict dove per ogni termine abbiamo una lista di definizioni.
#
# Nel seguente step otterremo una dictionary dove per ogni parola costruiamo una dictionary termine : frequenza, questa sarà usata per la ricerca del synset su wordnet tramite il principio del Genus
#
# Per farlo, per ognuno dei nostri 4 termini:
#
# 1. Concateniamo tutte le definizioni in una unica stringa.
# 2. Creiamo una lista di token dell'intera lista
# 3. filtriamo le parole che sono alfanumerici ( per rimuovere punteggiatura) e che non siano stop_words.
#
# Infine memorizziamo il lemma del termine e calcoliamo la frequenza di ogni parola.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from collections import Counter

#leggo da file
meanings_map = read_csv('defs.csv')

lm = WordNetLemmatizer()
#porter = PorterStemmer()
stop_words = set(stopwords.words('english'))

counter_map = {}
for word in meanings_map.keys():
    # concateno le frasi in una stringa
    definitions_join = ' '.join(meanings_map.get(word))
    # creo array di parole
    word_tokens = word_tokenize(definitions_join)
    # salvo i lemma filtrando stopwords e non alfanumerici
    list_definitio_word = [lm.lemmatize(w.lower()) for w in word_tokens if not w.lower() in stop_words and w.lower().isalnum()]
    #list_definitio_word = [porter.stem(w.lower()) for w in word_tokens if not w.lower() in stop_words and w.lower().isalnum()]
    counter_map[word] = dict(Counter(list_definitio_word))

# Esempio
pprint.pprint(counter_map)
# Out:
# {'Apprehension': {'abnormal': 1,
#                   'accada': 1,
#                   'act': 1,
#                   'agitated': 1,
#                   'agitation': 2,
#                   'ansia': 1,
#                   'anticipation': 1,
#                   'anxiety': 10,
#                   'awe': 1,
#                   'bad': 4,
#                   'brutto': 1,
#                   'cause': 1,
#                   'characterized': 1,
#                   'che': 1,
#                   'constant': 1,
#                   'derived': 1,
#                   'di': 1,
#                   'different': 1,
#                   'discomfort': 1,
#                   'disturbance': 1,
#                   'emotion': 2,
#                   'emotional': 1,
#                   'event': 1,
#                   'expectation': 1,
#                   'experience': 1,
#                   'fear': 10,
#                   'fearful': 1,
#                   'feel': 3,
#                   'feeling': 6,
#                   'frightened': 1,
#                   'future': 1,
#                   'happen': 5,
#                   'high': 1,
#                   'learning': 1,
#                   'loss': 1,
#                   'make': 2,
#                   'mental': 3,
#                   'mind': 3,
#                   'mood': 1,
#                   'moode': 1,
#                   'negative': 1,
#                   'nervousness': 1,
#                   'normal': 1,
#                   'one': 2,
#                   'particular': 1,
#                   'pathway': 1,
#                   'paura': 1,
#                   'person': 3,
#                   'preoccupation': 1,
#                   'qualcosa': 1,
#                   'restless': 1,
#                   'sadness': 1,
#                   'sense': 1,
#                   'situation': 2,
#                   'someone': 1,
#                   'something': 10,
#                   'spiacevole': 1,
#                   'state': 7,
#                   'status': 2,
#                   'strange': 2,
#                   'strangeness': 1,
#                   'unaccommodating': 1,
#                   'uncofortable': 1,
#                   'understanding': 1,
#                   'understood': 1,
#                   'unease': 1,
#                   'unexpected': 1,
#                   'unpleasant': 3,
#                   'upset': 1,
#                   'way': 1,
#                   'worry': 1},
#  'Courage': {'abiliity': 1,
#              'ability': 18,
#              'able': 3,
#              'act': 1,
#              'action': 2,
#              'allow': 1,
#              'allows': 4,
#              'aptitude': 1,
#              'avoid': 1,
#              'behavior': 1,
#              'beyond': 1,
#              'blocked': 1,
#              'characteristic': 1,
#              'choice': 2,
#              'considered': 1,
#              'control': 2,
#              'danger': 1,
#              'dangerous': 3,
#              'deal': 1,
#              'despite': 3,
#              'difficult': 3,
#              'difficulty': 1,
#              'drastic': 1,
#              'emotion': 1,
#              'expectation': 1,
#              'face': 9,
#              'fear': 17,
#              'fearful': 1,
#              'feeling': 2,
#              'frightened': 1,
#              'generally': 1,
#              'go': 1,
#              'hero': 1,
#              'human': 1,
#              'inner': 1,
#              'make': 4,
#              'may': 1,
#              'mental': 1,
#              'mind': 1,
#              'moral': 1,
#              'one': 1,
#              'overcome': 3,
#              'particular': 1,
#              'people': 2,
#              'perform': 1,
#              'persevere': 1,
#              'person': 1,
#              'property': 1,
#              'provoke': 1,
#              'quality': 1,
#              'resist': 1,
#              'risk': 1,
#              'risky': 1,
#              'scar': 1,
#              'scare': 1,
#              'scared': 2,
#              'scaring': 1,
#              'scary': 1,
#              'situation': 7,
#              'someone': 1,
#              'something': 7,
#              'strength': 3,
#              'take': 2,
#              'taking': 1,
#              'thaht': 1,
#              'thing': 2,
#              'typical': 1,
#              'u': 3,
#              'unpleasant': 1,
#              'unpleasent': 1,
#              'venture': 1,
#              'willing': 1,
#              'without': 2,
#              'withstand': 1},
#  'Paper': {'available': 1,
#            'cellulose': 7,
#            'communication': 1,
#            'composed': 2,
#            'context': 1,
#            'cortex': 1,
#            'crafted': 1,
#            'cut': 1,
#            'derived': 2,
#            'done': 1,
#            'draw': 1,
#            'drawing': 1,
#            'easily': 1,
#            'easy': 1,
#            'especially': 1,
#            'felted': 1,
#            'fiber': 1,
#            'fine': 1,
#            'flat': 1,
#            'folded': 1,
#            'generally': 2,
#            'handwriting': 1,
#            'information': 1,
#            'kind': 1,
#            'laid': 1,
#            'lightweight': 1,
#            'made': 4,
#            'material': 23,
#            'medium': 1,
#            'multiple': 1,
#            'note': 1,
#            'object': 1,
#            'obtained': 5,
#            'one': 2,
#            'packaging': 1,
#            'particular': 1,
#            'piece': 1,
#            'possible': 1,
#            'printing': 2,
#            'product': 3,
#            'purpose': 1,
#            'retrieve': 1,
#            'rip': 1,
#            'screen': 1,
#            'several': 1,
#            'sheet': 1,
#            'short': 1,
#            'something': 1,
#            'store': 1,
#            'student': 1,
#            'subject': 1,
#            'surface': 1,
#            'suspension': 1,
#            'taking': 1,
#            'thin': 2,
#            'tree': 5,
#            'type': 1,
#            'university': 1,
#            'used': 13,
#            'usually': 1,
#            'vegetable': 1,
#            'water': 1,
#            'wood': 6,
#            'write': 8,
#            'writing': 8,
#            'written': 2},
#  'Sharpener': {'allow': 1,
#                'allows': 3,
#                'blade': 2,
#                'clearer': 1,
#                'creating': 1,
#                'cut': 1,
#                'device': 2,
#                'edge': 1,
#                'end': 1,
#                'equipped': 1,
#                'graphite': 1,
#                'lead': 1,
#                'little': 1,
#                'make': 4,
#                'making': 2,
#                'mark': 1,
#                'mine': 2,
#                'object': 12,
#                'order': 1,
#                'pencil': 25,
#                'person': 2,
#                'refined': 1,
#                'returning': 1,
#                'shapen': 1,
#                'sharp': 4,
#                'sharpen': 16,
#                'sharpening': 2,
#                'sharper': 1,
#                'sharpner': 1,
#                'smooth': 1,
#                'something': 3,
#                'stationery': 1,
#                'tip': 2,
#                'tool': 16,
#                'use': 2,
#                'used': 15,
#                'working': 1,
#                'write': 2}}

# %% [markdown]
# ## Creiamo un metodo per semplificare l'estrazione delle k word più frequenti data una parola
# Questo ci servirà per applicare il principio del Genus
#
# Per farlo sfruttiamo il metodo sorted dove passiamo la dictionary, specifichiamo la key tramite lambda calcolo e settiamo la modalità reverse per ottenere in ordine decrescente.
#
# Al termine estriamo solo le prime K parole

# %%
def get_most_frequent_words(term, k= 99999):
    return [k for k, v in sorted(counter_map.get(term).items(), key=lambda item: item[1], reverse=True)][0:k]

# Esempio
print("Le prime 10 parole più frequenti per Apprehension sono:")
print(get_most_frequent_words('Apprehension', 10))
# Out:
# Le prime 10 parole più frequenti per Apprehension sono:
# ['something', 'fear', 'anxiety', 'state', 'feeling', 'happen', 'bad', 'feel', 'mind', 'mental']

# %% [markdown]
# # Definiamo ora una serie di metodi per calcolare l'overlap
# Ci serve un sistema per valutare i nostri synset per capire quale potrebbe essere quello più corretto tra gli iponimi dei nostri
# K termini estratti precedentemente.
#
# ## Metodo bag of word
#
# Il primo metodo `bag_of_words_for_synset(wn_syn)` dato un synset estrae una bag of word con le parole contenute negli esempi
# e definizioni. Il metodo di filtraggio è lo stesso dello step precedente.
#
# Per semplificare non son stati eseguiti conteggi sulle parole ripetute anche se avrebbe potuto portare ad una maggiore accuratezza durante la fase di overlapping.
#
# Il risultato è un set delle parole estratte

# %%
from nltk.corpus import wordnet as wn

def bag_of_words_for_synset(wn_syn):
    new_list = wn_syn.examples() + [wn_syn.definition()]
    sentence_concatenated = ' '.join(new_list)
    tokens = word_tokenize(sentence_concatenated)
    bag_of_words = [lm.lemmatize(w.lower()) for w in tokens if not w.lower() in stop_words and w.lower().isalnum()]
    #bag_of_words = [porter.stem(w.lower()) for w in tokens if not w.lower() in stop_words and w.lower().isalnum()]
    return dict(Counter(bag_of_words))

# Esempio
print(bag_of_words_for_synset(wn.synset('dog.n.01')))
# Out:
# {'dog': 1, 'barked': 1, 'night': 1, 'member': 1, 'genus': 1, 'canis': 1, 'probably': 1, 'descended': 1, 'common': 1, 'wolf': 1, 'domesticated': 1, 'man': 1, 'since': 1, 'prehistoric': 1, 'time': 1, 'occurs': 1, 'many': 1, 'breed': 1}

# %% [markdown]
# ## Metodo overlap
#
# Creiamo ora un metodo per calcolare l'overlap date due dict di bag of words, rispettivamente del synset e delle definizioni di partenza
#
# Questo metodo prese due dict restituisce il numero di intersezioni, dove un'intersezione avviene se due parole han lo stesso stemma.<br>
# Nota: l'overlap si basa sui valori dei contatori, se due parole compaiono entrambe con count pari a 2 il risultato sarebbe 4.

# %%
def compute_overlap(dict_a, dict_b):
    return sum(dict(Counter(dict_a) & Counter(dict_b)).values())

# Esempio
print(compute_overlap(counter_map.get('Apprehension'), bag_of_words_for_synset(wn.synset('apprehension.n.01'))))
# Out:
# 3

# %% [markdown]
# ## Cerchiamo il synset data la definizione
#
# Per ogni termine da cercare estriamo le 10 più frequenti parole usando
# ```get_most_frequent_words(word,10)```
#
# Per ognuna di esse, per ogni synset di tipo *noun*:
#         cicliamo su ogni iponimo e calcoliamo l'overlap del synset (dell'iponimo), estratto tramite il metodo `bag_of_words_for_synset`, con la dictionary calcolata precedentemente dalle nostre definizioni.
#
# Il risultato sarà salvato in una dictionary nuova

# %%
result_dict = {}
# Per ognuno dei nostri 4 termini:
for word in counter_map.keys():
    
    #Estriamo le 10 parole più frequenti nelle definizioni
    top_frequent_terms = get_most_frequent_words(word,10)
    inner_dict = {}
    
    for f_word in top_frequent_terms:
        for synset in wn.synsets(f_word, 'n'):

            if synset is not None:
                for hyp in synset.hyponyms():

                    if not inner_dict.__contains__(hyp):
                        bag_of_word_hyp = bag_of_words_for_synset(hyp)
                        overlap = compute_overlap(counter_map.get(word), bag_of_word_hyp)
                        inner_dict[hyp] = overlap

    result_dict[word] = inner_dict

for word in result_dict.keys():
    print(word)
    pprint.pprint(sorted(result_dict.get(word).items(), key=lambda item: item[1], reverse=True)[0:5])
    print("\n\n\n")
# Out:
# Courage
# [(Synset('physical_ability.n.01'), 5),
#  (Synset('penetration.n.04'), 3),
#  (Synset('stage_fright.n.01'), 3),
#  (Synset('countenance.n.03'), 3),
#  (Synset('ballgame.n.01'), 3)]
#
#
#
#
# Paper
# [(Synset('composite_material.n.01'), 5),
#  (Synset('paper.n.01'), 5),
#  (Synset('balsa.n.01'), 5),
#  (Synset('cedar.n.02'), 5),
#  (Synset('maple.n.01'), 5)]
#
#
#
#
# Apprehension
# [(Synset('feeling.n.01'), 5),
#  (Synset('condition.n.01'), 4),
#  (Synset('grace.n.01'), 4),
#  (Synset('situation.n.01'), 4),
#  (Synset('apprehension.n.01'), 3)]
#
#
#
#
# Sharpener
# [(Synset('drill.n.01'), 4),
#  (Synset('broadsword.n.01'), 4),
#  (Synset('jaws_of_life.n.01'), 3),
#  (Synset('plow.n.01'), 3),
#  (Synset('upset.n.04'), 3)]
